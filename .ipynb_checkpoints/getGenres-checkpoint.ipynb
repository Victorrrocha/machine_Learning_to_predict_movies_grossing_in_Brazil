# %%
import pandas as pd
import numpy as np

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = '1cddf16338776cbf2116371734a3e441'

# %%
search = tmdb.Search()

# %%
#GENRES DICT
genres = {
    28 : 'Action',
    12 : 'Adventure',
    16 : 'Animation',
    35 : 'Comedy',
    80 : 'Crime',
    99 : 'Documentary',
    18 : 'Drama',
    10751 : 'Family',
    14 : 'Fantasy',
    36 : 'History',
    27 : 'Horror',
    10402 : 'Music',
    9648 : 'Mystery',
    10749 : 'Romance',
    878 : 'Science Fiction',
    10770 : 'TV Movie',
    53 : 'Thriller',
    10752 : 'War',
    37 : 'Western'
}

# %%
movie = search.movie(query='The Avengers')

# %%
search.results[0]['genre_ids']
# Out:
# [878, 28, 12]

# %% [markdown]
# ### inserindo os gêneros na tabela

# %%
dataset = pd.read_csv("grossing2017-2011.csv")

# %%
generos = pd.DataFrame(dataset['título_original']).assign(genero='Placeholder', subgenero='Placeholder').transpose()

# %%
generos.head()
# Out:
#                                      0               1    \
# título_original  The Fate of the Furious  Justice league
# genero                       Placeholder     Placeholder
# subgenero                    Placeholder     Placeholder
#
#                                   2                3             4    \
# título_original  Beauty and the Beast  Despicable me 3  Wonder Woman
# genero                    Placeholder      Placeholder   Placeholder
# subgenero                 Placeholder      Placeholder   Placeholder
#
#                                      5               6            7    \
# título_original  Spider-man - Homecoming  Thor: Ragnarok        Logan
# genero                       Placeholder     Placeholder  Placeholder
# subgenero                    Placeholder     Placeholder  Placeholder
#
#                                     8            9             ...             \
# título_original  Minha mãe é uma peça 2    The Shack           ...
# ...

# %%
for title in generos:
    name = generos[title].título_original
    try:
        movie = search.movie(query=str(name))
        id_generos = search.results[0]['genre_ids'][0]
        generos[title].genero = genres[id_generos]
    except:
        continue
    try:
        id_subgeneros = search.results[0]['genre_ids'][1]
        generos[title].subgenero = genres[id_subgeneros]
        print(generos[title])
    except:
        continue
# Out:
# título_original    The Fate of the Furious
# genero                              Action
# subgenero                            Crime
# Name: 0, dtype: object
# título_original    Justice league
# genero                     Action
# subgenero               Adventure
# Name: 1, dtype: object
# título_original    Beauty and the Beast
# genero                           Family
# subgenero                       Fantasy
# Name: 2, dtype: object
# título_original    Despicable me 3
# genero                      Action
# subgenero                Animation
# Name: 3, dtype: object
# título_original    Wonder Woman
# genero                Adventure
# subgenero               Fantasy
# Name: 4, dtype: object
# título_original    Spider-man - Homecoming
# genero                              Action
# subgenero                        Adventure
# Name: 5, dtype: object
# título_original    Thor: Ragnarok
# genero                     Action
# subgenero               Adventure
# Name: 6, dtype: object
# ...

# %%
genero = generos.transpose()

# %%
genero.reset_index(inplace=True)

# %%
genero
# Out:
#                                       título_original       genero  \
# 0                             The Fate of the Furious       Action
# 1                                      Justice league       Action
# 2                                Beauty and the Beast       Family
# 3                                     Despicable me 3       Action
# 4                                        Wonder Woman    Adventure
# 5                             Spider-man - Homecoming       Action
# 6                                      Thor: Ragnarok       Action
# 7                                               Logan       Action
# 8                              Minha mãe é uma peça 2       Comedy
# 9                                           The Shack        Drama
# 10                                              Moana    Adventure
# 11                      The Guardians of the Galaxy 2       Action
# 12                                Fifty shades darker        Drama
# ...
