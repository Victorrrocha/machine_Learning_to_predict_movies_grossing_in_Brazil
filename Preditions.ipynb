# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("dataset_full.csv", index_col=False)

# %%
dataset.drop("Unnamed: 0", axis=1, inplace=True)

# %%
dataset
# Out:
#                    título_original           genero        subgenero  \
# 0          The Fate of the Furious           Action            Crime
# 1                   Justice league           Action        Adventure
# 2             Beauty and the Beast           Family          Fantasy
# 3                  Despicable me 3           Action        Animation
# 4                     Wonder Woman        Adventure          Fantasy
# 5          Spider-man - Homecoming           Action        Adventure
# 6                   Thor: Ragnarok           Action        Adventure
# 7                            Logan           Action            Drama
# 8           Minha mãe é uma peça 2           Comedy      Placeholder
# 9                        The Shack            Drama          Fantasy
# 10   The Guardians of the Galaxy 2           Action        Adventure
# 11             Fifty shades darker            Drama          Romance
# 12                          Wonder            Drama           Family
# ...
